# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('lena.jpg')

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
plt.hist(gray)
# Out:
# (array([[ 52.,  79.,  70., ...,   0.,   0.,   0.],
#         [ 54.,  77.,  66., ...,   0.,   0.,   0.],
#         [ 49.,  79.,  71., ...,   0.,   0.,   0.],
#         ...,
#         [ 12.,  95.,  42., ...,  23.,  84.,   0.],
#         [ 13.,  96.,  35., ...,  25.,  83.,   0.],
#         [  9., 102.,  35., ...,  24.,  83.,   0.]]),
#  array([ 20. ,  42.5,  65. ,  87.5, 110. , 132.5, 155. , 177.5, 200. ,
#         222.5, 245. ]),
#  <a list of 512 BarContainer objects>)

# %%
new_img=cv2.convertScaleAbs(img,5,10)

# %%
plt.imshow(new_img)

# %%
#img[i,j] =aplha*img[i,j]+beta

# %%
new_gray=cv2.cvtColor(new_img,cv2.COLOR_RGB2GRAY)

# %%
plt.hist(new_gray)
# Out:
# (array([[  0.,   0.,   6., ...,  14.,   6., 438.],
#         [  0.,   0.,   7., ...,  11.,  12., 435.],
#         [  1.,   2.,  10., ...,  11.,   6., 444.],
#         ...,
#         [  0.,   2.,   1., ...,  17.,  16., 466.],
#         [  0.,   2.,   0., ...,  24.,  12., 459.],
#         [  0.,   1.,   1., ...,  13.,   9., 478.]]),
#  array([105., 120., 135., 150., 165., 180., 195., 210., 225., 240., 255.]),
#  <a list of 512 BarContainer objects>)

# %%
#Threshold

# %%
plt.imshow(gray,cmap='gray')

# %%
ret,thr=cv2.threshold(gray,85,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thr,cmap='gray')
